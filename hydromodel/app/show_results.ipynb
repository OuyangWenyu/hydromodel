# %% [markdown]
# # 分析结果
#
# 这是一个用于分析模型率定后测试结果的 Jupyter Notebook。读取各个exp下面的结果文件看看。

# %%
import os
import sys
from pathlib import Path

sys.path.append(os.path.dirname(Path(os.path.abspath('')).parent))
import definitions
# Out:
# Please Check your directory:
# ROOT_DIR of the repo:  c:\Users\wenyu\source\repos\hydro-model-xaj
# DATASET_DIR of the repo:  c:\Users\wenyu\source\data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
metric_mean_file = Path(os.path.join(definitions.ROOT_DIR, "hydromodel", "example", "exp001", "basins_test_metrics_mean_all_cases.csv"))
metric_median_file = Path(os.path.join(definitions.ROOT_DIR, "hydromodel", "example", "exp001", "basins_test_metrics_median_all_cases.csv"))

# %%
metric_mean = pd.read_csv(metric_mean_file, index_col=0)
metric_median = pd.read_csv(metric_median_file, index_col=0)

# %%
metric_mean
# Out:
#                                                         Bias       RMSE  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng...  7.375642  68.828121
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng...  6.974014  68.593691
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng...  6.419529  68.147590
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n...  6.029742  66.819800
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  8.618705  68.573292
#
#                                                        ubRMSE      Corr  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng...  64.378429  0.757830
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng...  64.597338  0.751802
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng...  63.882810  0.760571
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n...  64.603456  0.761088
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  65.880955  0.761839
#
#                                                           R2       NSE  \
# ...

# %%
metric_median
# Out:
#                                                         Bias       RMSE  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng... -8.686357  59.076562
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng... -5.603691  58.698793
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng... -8.024811  58.140511
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n... -0.011817  57.233134
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  2.625880  57.063369
#
#                                                        ubRMSE      Corr  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng...  58.484378  0.790776
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng...  58.430702  0.790776
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng...  57.490787  0.793007
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n...  56.475955  0.778663
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  56.755029  0.785636
#
#                                                           R2       NSE  \
# ...
