# %% [markdown]
# # 分析结果
#
# 这是一个用于分析模型率定后测试结果的 Jupyter Notebook。读取各个exp下面的结果文件看看。

# %%
import os
import sys
from pathlib import Path

sys.path.append(os.path.dirname(Path(os.path.abspath('')).parent))
import definitions
# Out:
# Please Check your directory:
# ROOT_DIR of the repo:  c:\Users\wenyu\source\repos\hydro-model-xaj
# DATASET_DIR of the repo:  c:\Users\wenyu\source\data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
metric_mean_file = Path(os.path.join(definitions.ROOT_DIR, "hydromodel", "example", "exp51210", "basins_test_metrics_mean_all_cases.csv"))
metric_median_file = Path(os.path.join(definitions.ROOT_DIR, "hydromodel", "example", "exp51210", "basins_test_metrics_median_all_cases.csv"))

# %%
metric_mean = pd.read_csv(metric_mean_file, index_col=0)
metric_median = pd.read_csv(metric_median_file, index_col=0)

# %%
metric_mean
# Out:
#                                                          Bias        RMSE  \
# Dec01_09-24-03_LAPTOP-DNQOPPMSHFsourcesrep5000n...  26.711326  103.524316
# Nov30_10-56-14_LAPTOP-DNQOPPMSHFsourcesrep100ng...  21.660492  105.604284
# Nov30_11-07-01_LAPTOP-DNQOPPMSHFsourcesrep200ng...  26.464496  110.368233
# Nov30_11-34-24_LAPTOP-DNQOPPMSHFsourcesrep500ng...  25.741664  105.275155
# Nov30_13-25-46_LAPTOP-DNQOPPMSHFsourcesrep1000n...  28.111310  104.568917
# Nov30_15-02-37_LAPTOP-DNQOPPMSHFsourcesrep2000n...  28.394632  103.895819
# Nov30_16-44-51_LAPTOP-DNQOPPMSHFsourcesrep5000n...  26.711326  103.524316
# Nov30_21-06-06_DESKTOP-I3R66MPHFsourcesrep10000...  27.006888  103.341330
# Nov30_21-08-59_LAPTOP-DNQOPPMSHFsourcesrep100ng...  21.660492  105.604284
#
#                                                         ubRMSE      Corr  \
# Dec01_09-24-03_LAPTOP-DNQOPPMSHFsourcesrep5000n...   98.092878  0.780049
# Nov30_10-56-14_LAPTOP-DNQOPPMSHFsourcesrep100ng...  101.875206  0.759729
# ...

# %%
metric_median
# Out:
#                                                         Bias       RMSE  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng... -8.686357  59.076562
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng... -5.603691  58.698793
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng... -8.024811  58.140511
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n... -0.011817  57.233134
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  2.625880  57.063369
#
#                                                        ubRMSE      Corr  \
# Nov27_20-41-12_LAPTOP-DNQOPPMSHFsourcesrep100ng...  58.484378  0.790776
# Nov27_20-47-30_LAPTOP-DNQOPPMSHFsourcesrep200ng...  58.430702  0.790776
# Nov27_21-01-36_LAPTOP-DNQOPPMSHFsourcesrep500ng...  57.490787  0.793007
# Nov28_09-14-56_LAPTOP-DNQOPPMSHFsourcesrep1000n...  56.475955  0.778663
# Nov28_10-54-47_LAPTOP-DNQOPPMSHFsourcesrep2000n...  56.755029  0.785636
#
#                                                           R2       NSE  \
# ...
